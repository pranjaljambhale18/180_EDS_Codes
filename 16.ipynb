# %%
def sayHello():
  print("good morning")

sayHello()
# Out:
# good morning

# %%
def numbers():
  print("enter a number")
  number = int(input())
  if number%2 == 0:
    print("number",number ,"is even")
  else:
    print("number", number," is odd")
numbers()
# Out:
# enter a number
# 87
# number 87  is odd

# %%
a = 10
b = True
c = 16.55
d = [10, 20, 30]

#print(type(a))
#print(type(b))
#print(type(d))

print(abs(15.8907658964532398791111119112))
# Out:
# 15.89076589645324

# %%
11 = ["a", "b", "c"]
12 = ["", ""]
13 = ["a", "", ""]
# Out:
#   File "<ipython-input-70-1cf60bed4721>", line 1
#     11 = ["a", "b", "c"]
#     ^
# SyntaxError: cannot assign to literal

# %%
print(callable(type))
print(callable(all))
print(callable([10, 20, 30]))
print(callable(sayHello))
print(callable("Python"))
# Out:
# True
# True
# False
# True
# False

# %%
import statistics
set2 = [3,3,3,5,5,5]
print(statistics.mean(set1))
# Out:
# 28.25

# %%
from statistics import median
set1 = (23, 34, 65, 457, 58)
print(median(set1))
# Out:
# 58
