# %%
#Tuple Operations
import statistics
import pandas as pd

# Read the Excel file
df = pd.read_excel('/content/drive/MyDrive/HPSV.EDS.xls')

print(df)

tuple_data = tuple(map(tuple, df.values))

print(tuple_data)


operation1 = max(Price Paid)
operation2 = min(,Price Paid)
Operation3= sum(,Price Paid)
operation4 = statistics.median(,Price Paid)

print("max: ",operation1 )
# Out:
#   File "<ipython-input-12-4a1f786a2803>", line 15
#     operation1 = max(Price Paid)
#                      ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
