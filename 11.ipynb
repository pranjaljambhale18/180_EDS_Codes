# %%
a = "Hello, World!"
print(a[1])

b="good morning"
print(b[7])
# Out:
# e
# r

# %%
 for letter in "word":
    print(letter)
# Out:
# w
# o
# r
# d

# %%
line= "hey, have a great day"
print(" a " in line)
# Out:
# True

# %%
txt = "The best things in life are free!"

a=input(" ")

if a in txt:
  print(a, "is pesent")

elif a not in txt:
  print("no not there")

else :
  print("its okay")
# Out:
#  best
# best is pesent

# %%
txt = "The best things in life are free!"
if "expensive" not in txt:
  print("No, 'expensive' is NOT present.")
# Out:
# No, 'expensive' is NOT present.

# %%
b = "Hellouu,g World!"
print(b[2:5])
# Out:
# llo

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = " Hello, World! "
print(a.strip())

# %%
c = " hi i qam neha "
print(c.strip)

# %%
b = "good morning"
print(b)
# Out:
# good morning

# %%
s = "     harshada "
print(s.strip())
# Out:
# harshada

# %%
r = "hello dharti"
print(r.replace("d", "D"))
print(r.replace("h", "H"))
# Out:
# hello Dharti
# Hello dHarti

# %%
name = input(" ")
age = int(input( ))
print(" hi, my name is ", name, " and my age is", age)
# Out:
#  pranjal
# 19
#  hi, my name is  pranjal  and my age is 19

# %%
quantity = 36
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(quantity, itemno, price))
# Out:
# I want 36 pieces of item 567 for 49.95 dollars.

# %%
quantity = 36
itemno = 567
price = 49.95
myorder = "I want {} pieces of item {} for {} dollars."
print(myorder.format(itemno, quantity, price))
# Out:
# I want 567 pieces of item 36 for 49.95 dollars.

# %%
txt = "We are the so-called "Vikings" from the north."
print(txt)
# Out:
#   File "<ipython-input-58-485014d8dfdf>", line 1
#     txt = "We are the so-called "Vikings" from the north."
#                                  ^
# SyntaxError: invalid syntax

# %%
txt = "We are the so-called 'Vikings' from the north."
print(txt)
# Out:
# We are the so-called 'Vikings' from the north.

# %%
txt = "We are the so-called \"Vikings\" from the north."
print(txt)
# Out:
# We are the so-called "Vikings" from the north.

# %%
print("hello, her name is \"pranjal\"")
# Out:
# hello, her name is "pranjal"

# %%
d= "HELLO"
print(d.zfill(9))
# Out:
# 0000HELLO

# %%
print(bool("Hello"))
print(bool(15))
print(bool(12.76))
# Out:
# True
# True
# True

# %%
def myFunction() :
  return False

print(myFunction())
# Out:
# False

# %%
def myFunction() :
  return False

if myFunction():
  print("YES!")
else:
  print("NO!")
# Out:
# NO!

# %%
x = 200
print(isinstance(x, int))
# Out:
# True
