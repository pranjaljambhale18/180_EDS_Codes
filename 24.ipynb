# %%
print("'hello\ world'")
print('''hello bro''')
# Out:
# 'hello\ world'
# hello bro

# %%
a= 2
b=3
print(2a+b)
# Out:
#   File "<ipython-input-1-562b6fd45b77>", line 3
#     print(2a+b)
#           ^
# SyntaxError: invalid decimal literal

# %%
a=4.3
b=5.0
c=a+b
print(c)
# Out:
# 9.3

# %%
#(a=int(input)
#b=int(input)
#c=int(input)

#d=a>b and b>c
#if d:
 # print("ascending")
#else:
 # printy  )

# %%
#table of n
n = int(input("enter a number: "))
for i in range(1 ,11):
  print(n*i)
# Out:
# enter a number: 4
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40

# %%
#n = int(input("enter a number: "))
#i=1
#while i<11:
 # print(n*i)
#i=i+1


a= "harsh"
b= input()
if(a==b):
  print("true")
else:
  print("false")

if(a is b):
  print("true")
else:
  print("false")
# Out:
# harsh
# true
# false

# %%
name =input("enter your name: ")
if (name == "pranjal"):
  print("you're awesome")
else:
  print("hi", name, "pranjal is more awesome than you")
# Out:
# enter your name: har
# hi har pranjal is more awesome than you

# %%
name = input("enter your name: ")
if (name == "pranjal"):
  print(" you are awesome")
else:
  print("hi", name, "pranjal is more awesome than you")
# Out:
# enter your name: harshada
# hi harshada pranjal is more awesome than you
