# %%
age = input("what is your age? ")
print("you are", age , "years old")
print(type(age))
print("in 5 years your age will be ", int(age)+5)
# Out:
# what is your age? 19
# you are 19 years old
# <class 'str'>
# in 5 years your age will be  24

# %%
a = input(("what is your age? "))
print("your age is ", a)
print("in five years youll be ", int (a) +5)
(type(a))
# Out:
# what is your age? 19
# your age is  19
# in five years youll be  24
# str

# %%
print(9/2 == 4.5)
# Out:
# True

# %%
print(24.5//5)
# Out:
# 4.0

# %%
print(4.9*5)
# Out:
# 24.5

# %%
print(2**204)
# Out:
# 25711008708143844408671393477458601640355247900524685364822016

# %%
print(45%90)
# Out:
# 45

# %%
print(-1//2 == 1//-2)
# Out:
# True

# %%
a=5
b=5.0
c=5.00
d=5
print(id(a))
print(id(b))
print(id(c))
print(id(d))

print(c is not d)
# Out:
# 140566023225712
# 140565536986032
# 140565536989488
# 140566023225712
# True

# %%
z = "india is great"
print("  " not in z)
# Out:
# True

# %%
weather = input("how is the weather today? ")
if weather == "sunny":
  print("go for picnic")
elif weather == "windy":
  print("dry your clothes today")
else:
  print("salman khan")
# Out:
# how is the weather today? cold
# salman khan
