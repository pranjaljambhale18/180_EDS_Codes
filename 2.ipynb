# %%
import pandas as pd
df = pd.read_excel(r'/content/drive/MyDrive/delhi school kaggle.xltx')
b = pd.DataFrame(df)
print(b)
# Out:
#       S.No    District  Zone  School ID  \
# 0        1        East     1    1001152
# 1        2        East     1    1001153
# 2        3        East     1    1001155
# 3        4        East     1    1001156
# 4        5        East     1    1001158
# ...    ...         ...   ...        ...
# 1369  1370  South East    29    1925409
# 1370  1371  South East    29    1925416
# 1371  1372  South East    29    1925427
# 1372  1373  South East    29    1925435
# 1373  1374  South East    29    1925445
#
#                                             School Name  \
# 0                              GREEN LAND PUBLIC SCHOOL
# 1                      GEETA BAL BHARTI SR. SEC. SCHOOL
# 2                              GYANDEEP SHIKSHA NIKETAN
# 3                                  PUNEET PUBLIC SCHOOL
# 4                                   HAPPY PUBLIC SCHOOL
# ...                                                 ...
# 1369                                  Mir Public School
# ...

# %%
a = df['District']
print(a)
# Out:
# 0             East
# 1             East
# 2             East
# 3             East
# 4             East
#            ...
# 1369    South East
# 1370    South East
# 1371    South East
# 1372    South East
# 1373    South East
# Name: District, Length: 1374, dtype: object

# %%
b = df['School ID']
print(b)
# Out:
# 0       1001152
# 1       1001153
# 2       1001155
# 3       1001156
# 4       1001158
#          ...
# 1369    1925409
# 1370    1925416
# 1371    1925427
# 1372    1925435
# 1373    1925445
# Name: School ID, Length: 1374, dtype: int64

# %%
import matplotlib.pyplot as plt

xpoints = a
ypoints = b
plt.scatter(xpoints, ypoints)
plt.show()

#bar plot scatter

# %%
import matplotlib.pyplot as plt

xpoints = a
ypoints = b
plt.bar(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt

xpoints = a
ypoints = b
plt.pie(ypoints)
plt.show()

# %%
import pandas as pd
df1 = pd.read_excel('/content/drive/MyDrive/delhi school kaggle.xltx')
data = df1.values.tolist()
b = pd.DataFrame(df1)

u = df1['Zone']
v = df1['District']

df1.Zone = df1.Zone.astype('int64')
d =  df1['District'][df1.Zone<25]

def schools(u, v):
  a=df1.groupby('District')['Shift'].count()==2
  b=df1.groupby('District')['Shift'].head()
  print(a)
  print(b)
  c=df.aggregate(['sum', 'max', 'min'])
  print(c)
  plt.plot(xpoints, ypoints)
  #list and for loop

schools(u,v)
# Out:
# District
# Central         False
# East            False
# New Delhi       False
# North           False
# North East      False
# North West A    False
# North West B    False
# South           False
# South East      False
# South West A    False
# South West B    False
# West A          False
# West B          False
# Name: Shift, dtype: bool
# 0       Morning
# 1       Morning
# 2       Morning
# 3       Morning
# 4       Morning
#          ...
# 1294    Morning
# 1295    Morning
# 1296    Morning
# 1297    Morning
# 1298    Morning
# Name: Shift, Length: 65, dtype: object
#        S.No                                           District   Zone  \
# sum  944625  EastEastEastEastEastEastEastEastEastEastEastEa...  18983
# max    1374                                             West B     29
# min       1                                            Central      1
#
#       School ID                                        School Name  \
# ...

# %%
avg = lambda x,y,z:(x+y+z)/3
print(avg(2,3,4))
# Out:
# 3.0

# %%
import matplotlib.pyplot as plt
import numpy as np

x_points = np.array([0, 6])
y_points = np.array([0, 250])

plt.plot(x_points, y_points, 'o')
plt.show()
