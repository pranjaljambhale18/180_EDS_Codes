# %%
import pandas as pd
df = pd.read_excel(r'/content/drive/MyDrive/govt census 2001.xlsx')
b = pd.DataFrame(df)
print(b)
# Out:
#      Unnamed: 0   State                                           District  \
# 0             1      AN  District Andamans (01), Andaman & Nicobar Isla...
# 1             2      AN  District Nicobars (02), Andaman & Nicobar Isla...
# 2             3  Andhra        District Adilabad (01), Andhra Pradesh (28)
# 3             4  Andhra       District Nizamabad (02), Andhra Pradesh (28)
# 4             5  Andhra      District Karimnagar (03), Andhra Pradesh (28)
# ..          ...     ...                                                ...
# 585         586      WB           District Puruliya (14), West Bengal (19)
# 586         587      WB                                 District Medinipur
# 587         588      WB                                     District Haora
# 588         589      WB            District Kolkata (17), West Bengal (19)
# 589         590      WB        Twenty Four Parganas (18), West Bengal (19)
#
# ...

# %%
a= df['State']
print(a)
# Out:
# 0          AN
# 1          AN
# 2      Andhra
# 3      Andhra
# 4      Andhra
#         ...
# 585        WB
# 586        WB
# 587        WB
# 588        WB
# 589        WB
# Name: State, Length: 590, dtype: object

# %%
b=df['District']
print(b)
# Out:
# 0      District Andamans (01), Andaman & Nicobar Isla...
# 1      District Nicobars (02), Andaman & Nicobar Isla...
# 2            District Adilabad (01), Andhra Pradesh (28)
# 3           District Nizamabad (02), Andhra Pradesh (28)
# 4          District Karimnagar (03), Andhra Pradesh (28)
#                              ...
# 585             District Puruliya (14), West Bengal (19)
# 586                                   District Medinipur
# 587                                       District Haora
# 588              District Kolkata (17), West Bengal (19)
# 589          Twenty Four Parganas (18), West Bengal (19)
# Name: District, Length: 590, dtype: object

# %%
c= df['Persons']
print(c)
# Out:
# 0       314084
# 1        42068
# 2      2488003
# 3      2345685
# 4      3491822
#         ...
# 585    2536516
# 586    9610788
# 587    4273099
# 588    4572876
# 589    6906689
# Name: Persons, Length: 590, dtype: int64

# %%
import matplotlib.pyplot as plt

xpoints = a
ypoints = b
plt.scatter(xpoints, ypoints)
plt.show()

# %%
plt.bar(xpoints, ypoints)
# Out:
# <BarContainer object of 590 artists>

# %%
plt.plot(xpoints, ypoints)

# %%
plt.pie(c)
plt.show()

# %%
a = df.groupby('State')['Persons'].count()
print(a)
# Out:
# State
# AN                   2
# Andhra              22
# ArunachalPradesh    13
# Assam               23
# Bihar               37
# CG                  16
# Chandigarh           1
# D_D                  2
# D_N_H                1
# Delhi                9
# Goa                  2
# Gujarat             25
# HP                  12
# Haryana             19
# JK                  14
# Jharkhand           18
# Karnataka           27
# Kerala              14
# Lakshdweep           1
# MP                  45
# Maharashtra         35
# Manipur              8
# Meghalya             7
# Mizoram              8
# Nagaland             8
# Orrisa              29
# Pondicherry          4
# Punjab              17
# Rajasthan           32
# Sikkim               4
# TN                  30
# Tripura              4
# UP                  70
# Uttranchal          13
# WB                  18
# Name: Persons, dtype: int64

# %%
b = df.groupby('Males')['Females'].head()
print(b)
# Out:
# 0       143765
# 1        19415
# 2      1237045
# 3      1182780
# 4      1743854
#         ...
# 585    1238438
# 586    4694418
# 587    2031201
# 588    2072836
# 589    3341696
# Name: Females, Length: 590, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/govt census 2001.csv')
data = df.values.tolist()
d = pd.DataFrame(df)

e = df['Females']
f = df['Males']

df.Females = df.Females.astype('int64')
h = df['Males'][df.Females>25]


df.Males = df.Males.astypr('int64')
df['Females'][df.Males>5677]



def india():
  for row in df:
    df.Males = df.Males.astype('int64')
df['Females'][df1.Males>2]

while row is int:
  df.Females = df.Females.astype('int64')
g=df['Males'][df.Females>2]

print(g)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-62ed990ca3ad> in <cell line: 13>()
#      11
#      12
# ---> 13 df.Males = df.Males.astypr('int64')
#      14 df['Females'][df.Males>5677]
#      15
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'astypr'

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/STUDENT MARKS DATA - Sheet1.csv')
a = df.head()

x= df.iloc[:, :-1]
y= df.iloc[:,1]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train , y_test = train_test_split(x,y,test_size= 1/3, random_state= 0)

print(x_train)
