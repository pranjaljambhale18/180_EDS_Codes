# %%
import statistics
set1 = [1,3,3,4,5,7,8]
print("median hgh of the set is", statistics.median_high(set1))
# Out:
# median hgh of the set is 4

# %%
import statistics
set1 = [1,2,3,4,5,4,3,2,1,2,3,3,3,3,6,78,9]
print("the mode is %s" % statistics.mode(set1))
# Out:
# the mode is 3

# %%
list = [1,2,3,4,5,86]
maximum = max(list)
minimum = min(list)
range = maximum - minimum
print("maximum = {}, minimum = {}, range = {}".format(maximum, minimum, range))
# Out:
# maximum = 86, minimum = 1, range = 85

# %%
import statistics
set_of_numbers = [1,2,3,4,5,6]
print("the variance is", variance(set_of_numbers))
# Out:
# the variance is 3.5

# %%
from statistics import stdev
set = [1,2,3,4,5,6]
print(stdev(set))
# Out:
# 1.8708286933869707

# %%
from statistics import mode
set = [1,2,3,4,5,6,7,8,90]
print(mode(set))
# Out:
# 1

# %%
import pandas as pd
df = pd.read_excel(r'/content/drive/MyDrive/Book1.xlsx')
print(df)
# Out:
#     Sr. No.      Employee name    Employee I'D  Age  Date Of birth
# 0         1     Juber Maindarge   202201090001    23    2004-11-01
# 1         2       Shruti Garad    202201090002    26    2004-11-02
# 2         3        Yash Kumbhar   202201090114    28    2004-11-03
# 3         4    Swastik Paratkar   202201090004    25    2004-11-04
# 4         5       Ashraf Shaikh   202201090004    21    2004-11-05
# 5         6  Bhagyashree Thakur   202201090005    29    2004-11-06
# 6         7     Hitarth Paliwal   202201090006    28    2004-11-07
# 7         8            Vaibhav    202201090007    32    2004-11-08
# 8         9      Ramani Vemula    202201090008    26    2004-11-09
# 9        10          Neil Desai   202201090009    24    2004-11-10
# 10       11   Gandharva Jhadav   2022010900010    29    2004-11-11
# 11       12      Shalom Jadhav   2022010900011    25    2004-11-12
# 12       13  Prathemesh Chavan   2022010900012    33    2004-11-13
# ...

# %%
import pandas as pd
df.sort_values(by=[''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-15d13e816dab> in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df.sort_values(by=['Age'])
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6320
#    6321             by = by[0]
# -> 6322             k = self._get_label_or_level_values(by, axis=axis)
#    6323
#    6324             # need to rewrap column in Series to apply key function
#
# ...
