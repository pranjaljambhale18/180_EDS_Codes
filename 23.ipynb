# %%
print("hello")
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %%
first_name = "tony"
last_name = "stark"
age = 51
is_genius = True

# %%
name = input("what is your name? ")
print("her name is" , name)
# Out:
# what is your name? gg
# her name is gg

# %%
name = input("tony, what is your superhero name?")
print(name)

# %%
old_age = int(input("enter your old age? "))
new_age = old_age + 2
print(new_age)
# Out:
# enter your old age? 99
# 101

# %%
l=list('lockdown')
p=list("hello_world")
print(p)
print(l)
# Out:
# ['h', 'e', 'l', 'l', 'o', '_', 'w', 'o', 'r', 'l', 'd']
# ['l', 'o', 'c', 'k', 'd', 'o', 'w', 'n']

# %%
l1=[1,2,3,4,5]
l2=[1,2,11,12,13,14,15]
l3=l1+l2
print(l3)
# Out:
# [1, 2, 3, 4, 15, 5, 1, 2, 11, 12, 13, 14, 15]

# %%
A=[]
for i in range(1,4):
  A.append(i)
  print(A)
# Out:
# [1]
# [1, 2]
# [1, 2, 3]
