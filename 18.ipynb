# %%
s1 = {2:3,4:'hello'}
s2 = {1.45, 6.67, "hello", (1, 2, 3)}
print(s1)
print(s2)
# Out:
# {2: 3, 4: 'hello'}
# {1.45, (1, 2, 3), 'hello', 6.67}

# %%
a = {10, 20, 30}
print(a)
# Out:
# {10, 20, 30}

# %%
a = {1, 2, 3, 4}
for i in a:
  print(i*"*")
# Out:
# *
# **
# ***
# ****

# %%
sett = {1, 2, 3, 4}
sett.add(5)
print(sett)
# Out:
# {1, 2, 3, 4, 5}

# %%
sett.update({[92, 23, 24]})
print(sett)
# Out:
# {1, 2, 3, 4, 5, 22, 23, 24, 92}

# %%
sett.discard(4)
print(sett)
# Out:
# {1, 2, 3, 5, 22, 23, 24, 92}

# %%
q = {76, 77, 78, 79, 80}
p = {34, 35, 76, 37, 38}
w = q|p
print(w)
# Out:
# {34, 35, 37, 38, 76, 77, 78, 79, 80}

# %%
t = p & q
print(t)
# Out:
# {76}

# %%
d = p-q
print(d)
# Out:
# {34, 35, 37, 38}

# %%
d = q-p
print(d)
# Out:
# {80, 77, 78, 79}

# %%
m = p^q
print(m)
# Out:
# {77, 78, 79, 80, 34, 35, 37, 38}

# %%
m = q^p
print(m)
# Out:
# {77, 78, 79, 80, 34, 35, 37, 38}

# %%
dictionary = {"ABC": 123456789, "DEF": 987654321}
print(dictionary)
print(dictionary.keys())
print(dictionary.values())
dictionary.update({"GHI": 6574839201})
print(dictionary)
a = dictionary.__len__()
print(a)
dictionary.pop("ABC")
print(dictionary)
# Out:
# {'ABC': 123456789, 'DEF': 987654321}
# dict_keys(['ABC', 'DEF'])
# dict_values([123456789, 987654321])
# {'ABC': 123456789, 'DEF': 987654321, 'GHI': 6574839201}
# 3
# {'DEF': 987654321, 'GHI': 6574839201}

# %%
dictionary1= {"number": 45, "name": "pranjal", "age": 19, "place": "Pune"}

keys_for_slicing = ["name", "place"]

sliced_dict = {key: dictionary1[key] for key in keys_for_slicing}
print(sliced_dict)
# Out:
# {'name': 'pranjal', 'place': 'Pune'}
