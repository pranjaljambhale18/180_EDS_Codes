# %%
thislist = ["apple", "banana", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
print(len(thislist))
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']
# 5

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist))
# Out:
# 3

# %%
list1 = ["apple", "banana", "cherry"]
list2 = [1, 5, 7, 9, 3]
list3 = [True, False, False]
print(type(list2))
# Out:
# <class 'list'>

# %%
alist = list((11, 12, 13, 14, 15))
print(alist)
# Out:
# [11, 12, 13, 14, 15]

# %%
thislist = ["apple", "banana", "cherry"]
print(thislist[1])
thislist[2] = "pineapple"
print(thislist)
# Out:
# banana
# ['apple', 'banana', 'pineapple']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "melon", "mango"]
print(thislist[-4:-1])
if "kiwi" in thislist:
  print("it is present.")
else:
  print("not present")
# Out:
# ['orange', 'kiwi', 'melon']
# it is present.

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ("blackcurant", "pineapple")
print(thislist)
# Out:
# ['apple', 'blackcurant', 'pineapple', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
thislist.insert(3, "lemon")
print(thislist)



thislist.append("lemon")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'lemon', 'orange']
# ['apple', 'banana', 'cherry', 'lemon', 'orange', 'lemon']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
thislist2 = ["helo", "jhk", "hdd"]
thislist.extend(thislist2)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'helo', 'jhk', 'hdd']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
thislist = ["apple", "banana", "cherry", "orange"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
thislist.pop(2)
print(thislist)
# Out:
# ['apple', 'banana', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
thislist.remove("cherry")
print(thislist)
# Out:
# ['apple', 'banana', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
for fruit in thislist:
  print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry", "orange"]
for vegies in thislist:
  print(vegies)
# Out:
# apple
# banana
# cherry
# orange

# %%
fruits = ["apple", "banana", "cherry", "orange"]
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry
# orange

# %%
fruits = ["apple", "banana", "cherry", "orange"]
print(len(fruits))
# Out:
# 4

# %%
fruits = ["apple", "banana", "cherry", "orange", "hello", "helli"]
for i in range(len(fruits)):
  print(fruits[i])
# Out:
# apple
# banana
# cherry
# orange
# hello
# helli

# %%
fruits = ["apple", "banana", "cherry", "orange", "hello", "helli"]
for fruit in fruits:
  print(fruit)
# Out:
# apple
# banana
# cherry
# orange
# hello
# helli

# %%
eyy = ["apple", "banana", "cherry", "orange", "hello", "helli"]
i=0
while i < len(eyy):
  print(eyy[i])
i = i + 1

# %%
'''
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
  '''
# Out:
# ' \nthislist = ["apple", "banana", "cherry"]\ni = 0\nwhile i < len(thislist):\n  print(thislist[i])\n  i = i + 1 \n  '

# %%
thislist = ["apple", "banana", "cherry"]
[print(fruit) for fruit in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
print("h")
# Out:
# h

# %%
names = ["khuhu", "mmm", "gghg", "ddd", 'sxsub']
newlist = []

for name in names:
  if "h" in name:
    newlist.append(name)


newlist = ['hello' for name in names]
print(newlist)
# Out:
# ['hello', 'hello', 'hello', 'hello', 'hello']

# %%
newlist = [name for name in range(10) if name=="khuhu" ]
print(newlist)

# %%
fruits1 = ["banana", "apple","apple1", "cherry", "tomato", "pineapple"]
fruits1.sort(reverse=False)
print(fruits1)
# Out:
# ['apple', 'apple1', 'banana', 'cherry', 'pineapple', 'tomato']

# %%
thislist123 = ["zebra", "Zebra", "ZeBrA", "ZEBRA"]
thislist123.sort()
print(thislist123)
# Out:
# ['ZEBRS', 'ZeBrA', 'Zebra', 'zebra']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.sort(key=str.upper)
print(thislist)
# Out:
# ['banana', 'cherry', 'Kiwi', 'Orange']

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
thislist = ["apple", "Orange", "banana", "Pineapple"]
thislist.sort(key=str.lower)
print(thislist)
# Out:
# ['apple', 'banana', 'Orange', 'Pineapple']

# %%
thislist = ["apple", "Orange", "banana", "Pineapple"]
a = thislist.copy()
print(a)
print(thislist)
# Out:
# ['apple', 'Orange', 'banana', 'Pineapple']
# ['apple', 'Orange', 'banana', 'Pineapple']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)

# %%
thislist = ["apple", "banana", "cherry"]
k= list(thislist)
print(k)
# Out:
# ['apple', 'banana', 'cherry']

# %%
p=[45, 46, 67]
q=[2, 77, 943]
r = p+q

print(r)
# Out:
# [45, 46, 67, 2, 77, 943]

# %%
listqwe = ["a", "b", "c"]
listrty = [1, 2, 3]

listqwe.extend(listrty)
print(listqwe)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))
# Out:
# <class 'tuple'>

# %%
thistuple = ("apple", "banana", "cherry")
print(type(thistuple))
print(thistuple[-1])
# Out:
# <class 'tuple'>
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:
  print("yesss")
# Out:
# yesss

# %%
x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)

# %%
a = ("khushi", "shravani", "sanjay", "shamla", "tiku")
b = list(a)
b[1] = "pinki"
a = tuple(b)

print(a)
# Out:
# ('khushi', 'pinki', 'sanjay', 'shamla', 'tiku')

# %%
age = (12, 23, 45, 34 , 35)
shizz = list(age)
shizz[4] = 99
age = tuple(shizz)

print(age)
# Out:
# (12, 23, 45, 34, 99)

# %%
name = ("wer", "weddd", "bfvhv")
y = list(name)
y.append("sghb")
name = tuple(y)
print(name)
# Out:
# ('wer', 'weddd', 'bfvhv', 'sghb')

# %%
name = ("wer", "weddd", "bfvhv")
name1 = ("fffff",)
name = name +name1
print(name)
# Out:
# ('wer', 'weddd', 'bfvhv', 'fffff')

# %%
#Convert the tuple into a list, remove "apple", and convert it back into a tuple:


tuple1  = ("helo", "errrr", "teg" )
list1 = list(tuple1)
list1.remove("helo")
tuple1 = tuple(list1)

print(tuple1)
# Out:
# ('errrr', 'teg')

# %%
name = ("aa", "bb", "cc", "dd", "ee")
(a, *b, c, d) = name
print( b)
# Out:
# ['bb', 'cc']

# %%
tuple1  = ("helo", "errrr", "teg" )
for a in tuple1:
  print(a)
# Out:
# helo
# errrr
# teg

# %%
tuple1  = ("helo", "errrr", "teg" )
for i in range(len(tuple1)):
  print(tuple1[i])
# Out:
# helo
# errrr
# teg

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
tuple1  = ("helo", "errrr", "teg" )

i=0
while i<len(tuple1):
  print(tuple1[i])
  i=i+1
# Out:
# helo
# errrr
# teg

# %%
fruits = ("apple", "banana", "cherry", "apple")

print(fruits[1])
# Out:
# banana

# %%
t1 = ("l", 77)
t2 = ("w", 44)
t3 = t1 + t2
print(t3)
# Out:
# ('l', 77, 'w', 44)

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}

print(thisset)
# Out:
# {True, 2, 'apple', 'cherry', 'banana'}

# %%
thisset = {"apple", "banana", "cherry", True, 1, 2}
print(1.0000 in thisset)
# Out:
# True

# %%
a = {1, 2, 3}
b = {6, 7, 8}
a.update(b)
print(a)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
a = {1, 2, 3}
b = [6, 7, 8]
a.update(b)
print(a)
# Out:
# {1, 2, 3, 6, 7, 8}

# %%
thisset = {"apple", "banana", "cherry","lion" ,False, 1, 2}
z = thisset.pop()
thisset.discard("banana")

print(thisset)
# Out:
# {1, 2, 'lion', 'apple', 'cherry'}

# %%
a = {1, 2, 3, 6}
b = {6, 7, 8}
c = a.intersection(b)
print(c)
# Out:
# None

# %%
a = {1, 2, 3, 6}
b = {6, 7, 8}
c = a.intersection(b)
print(c)
# Out:
# {6}

# %%
a = {1, 2, 3, 6}
b = {6, 7, 8}
c = a.symmetric_difference(b)
print(c)
# Out:
# {1, 2, 3, 7, 8}

# %%
a = {1, 2, 3, 6, 13, 14}
b = {6, 7, 8, 11, 14}
c = a.symmetric_difference_update(b)
print(c)
# Out:
# None

# %%
thisdict = {"brand": "Ford", "model": "Mustang", "year": 1964}
print(thisdict)
print(thisdict["brand"])
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# Ford

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964,
  "year": 2020,
  "year": 6666
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 6666}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
x = thisdict["model"]
print(x)
# Out:
# Mustang

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(thisdict["model"])
# Out:
# Mustang

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict["brand"])
# Out:
# Ford

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

print(thisdict.get("brand"))
# Out:
# Ford

# %%
x= thisdict.keys()
print(x)
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
a= thisdict.values()
print(a)
# Out:
# dict_values(['Ford', 'Mustang', 1964])

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

thisdict["colour"] = "red"
thisdict["year"] = 2004


print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2004, 'colour': 'red'}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

x = thisdict.keys()
y = thisdict.values()
print(x, y)
# Out:
# dict_keys(['brand', 'model', 'year']) dict_values(['Ford', 'Mustang', 1964])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

print( "Ford" in car)
x = car.items()

print(x)

car["year"] = 2020

print(x) #after the change
# Out:
# False
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 1964)])
# dict_items([('brand', 'Ford'), ('model', 'Mustang'), ('year', 2020)])

# %%
car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964
}

car.update({"brand": "Foord"})
print(car)
# Out:
# {'brand': 'Foord', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
thisdict.update({"rrr": 1964})

print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'rrr': 1964}

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for x in thisdict.values():
  print(x)
# Out:
# Ford
# Mustang
# 1964

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for x in thisdict.keys():
  print(x)
# Out:
# brand
# model
# year

# %%
thisdict = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}

for x in thisdict.items():
  print(x)
# Out:
# ('brand', 'Ford')
# ('model', 'Mustang')
# ('year', 1964)

# %%
a = 33
b = 200
if not (a > b):
  print("a is NOT greater than b")
# Out:
# a is NOT greater than b

# %%
i = 1
while i < 60:
  print(i)
  i += 1

# %%
i = 1
while i < 6:
  print(i)
  i += 1
else:
  print("i is no longer less than 6")
# Out:
# 1
# 2
# 3
# 4
# 5
# i is no longer less than 6

# %%
def double(x):
  return x*2

print(double(5))
# Out:
# 15

# %%
def multiply(x):
  print(x*2)

print(multiply(6))
# Out:
# 12
# None

# %%
double = lambda n: n+n

print(double(99))
# Out:
# 198

# %%
cube = lambda m: m*m*m
print(cube(2))
# Out:
# 8

# %%
avg = lambda x, y: (x+y)/2
print(avg(3,5.2))
# Out:
# 4.1

# %%
def i(x, xx):
  return 6 + x(xx)

print(i(double , 2))
# Out:
# 10
