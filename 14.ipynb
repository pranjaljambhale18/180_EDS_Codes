# %%
numbers = [1,2,3,4,"five", "six","seven", "eight", "nine", "qw", "er", "gh"]

print(1 in numbers)
# Out:
# True

# %%
numbers = [1,2,3,4,"five", "six","seven", "eight", "nine", "qw", "er", "gh"]

i=1

while i<=(len(numbers)):
  print(numbers)
  i=i+1
# Out:
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']
# [1, 2, 3, 4, 'five', 'six', 'seven', 'eight', 'nine', 'qw', 'er', 'gh']

# %%
numbers = [1,2,3,4,"five", "six","seven", "eight", "nine", "qw", "er", "gh"]

numbers.clear()
print(numbers)
# Out:
# []

# %%
names = ["sanjay", "ab", "ac", "qw", "gd", "zz", "zzz"]
for name in names:
  if name == "zz":
    break
  print(name)
# Out:
# sanjay
# ab
# ac
# qw
# gd

# %%
names = ["sanjay", "ab", "ac", "qw", "gd","soab", "zz", "zzz"]
for name in names:
  if name == "soab":
    break
  print(name)
# Out:
# sanjay
# ab
# ac
# qw
# gd

# %%
tuple1 = (1,2,3,4,5,98)
tuple1(0, 99)
print(tuple1)

# %%
tuplee = (12, 13, 14, 15, 12, 12, 12, 13, 132)
print(tuplee.count(13))
# Out:
# 2

# %%
tuplee = (12, 13, 14, 15, 12, 12, 12, 13, 132)
print(tuplee.index(132))
# Out:
# 8

# %%
tuplee = (12, 13, 14, 15, 12, 12, 12, 13, 132)
print(len(tuplee))
# Out:
# 9

# %%
tuplee = (12, 13, 14, 15, 12, 12, 12, 13, 132)
print(tuplee.count(13))
# Out:
# 2

# %%
sett = {12, 13, 14, 15, 12, 12, 12, 13, 132}
print(sett)
# Out:
# {132, 12, 13, 14, 15}

# %%
sett = {12, 13, 14, 15, 12, 12, 12, 13, 132}
print(len(set))
# Out:
# 5

# %%
dikshionary = {"a": 97,"B": 86,"C":99}
#print(dikshionary["C"])

dikshionary["D"]=89
print(dikshionary)
# Out:
# {'a': 97, 'B': 86, 'C': 99, 'D': 89}

# %%
dic = {"radha": 97, "krishna": 96, "sai": 88}

dic["balkishan"]= 99
dic["govinda"]= 98
print(dic)
# Out:
# {'radha': 97, 'krishna': 96, 'sai': 88, 'balkishan': 99, 'govinda': 98}

# %%
print("while")
# Out:
# while

# %%
print(callable(int))
print(callable(float))
print(callable(str))
print(callable(bool))
# Out:
# True
# True
# True
# True

# %%
in built function
int()
bool()
float()
str()
# Out:
#   File "<ipython-input-2-d371ed42ade6>", line 1
#     in built function
#     ^
# SyntaxError: invalid syntax

# %%
from math import sqrt
print(sqrt(27))
# Out:
# 5.196152422706632

# %%
print(27**2)
# Out:
# 729

# %%
def sum(a, b=3):
  print(a+b)

sum(9)
# Out:
# 12

# %%
def CalculateMean(a,b):
  mean = (a*b)/(a+b)
  print(mean)

a= 5
b=4

CalculateMean(a,b)
# Out:
# 2.2222222222222223

# %%
marks = [2,2,2,1.9,2.1]

sum = marks[0] + marks[1] + marks[2] + marks[3] + marks[4]

length = len(marks)

avg_marks = sum / length

print(avg_marks)
# Out:
# 2.0

# %%
def average_marks(marks):
  total_marks = sum(marks)
  total_subjects = len(marks)
  avearge = total_marks / total_subjects
  return avaerage
