# %%
A = (1, 2,"pranjal")
print(A)
# Out:
# (1, 2, 'pranjal')

# %%
d1 = {98 = 98, 200.98 : 200.98, 976 : 976}
print(d1)
# Out:
# {98: 98, 200.98: 200.98, 976: 976}

# %%
a = 256j
print(a,"a as comlex decimal:", a, "good morning", "hello", a)
# Out:
# 256j a as comlex decimal: 256j good morning hello 256j

# %%
a = int(input())
b = int(input())
c = int(input())
if a>b and a>c :
  print(a)
if b>a and b>c :
  print(b)
if c>a and c>b :
  print(c)
# Out:
# 2
# 1
# 21
# 21
