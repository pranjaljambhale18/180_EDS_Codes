# %%
print(chr(67))
# Out:
# C

# %%
z= "hello_world"
print(z[4:7])
print(z[3:])
print(z[::-1])
print(z[::])
print(z[::2])
# Out:
# o_w
# lo_world
# dlrow_olleh
# hello_world
# hlowrd

# %%
st= input()
r = st[::-1]
if st==r:
  print("the word is a parendrome")
else:
  print("its like any other word")
# Out:
# 3e3
# the word is a parendrome

# %%
l=list("hello", 23, 4.56, "r")
print(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-a014fa94ff17> in <cell line: 1>()
# ----> 1 l=list("hello", 23, 4.56, "r")
#       2 print(l)
#
# TypeError: list expected at most 1 argument, got 4
